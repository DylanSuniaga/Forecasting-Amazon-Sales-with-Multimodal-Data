# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('./../data/all_keywords_merged.csv')

# %%
df.head()
# Out:
#                                     keyword  \
# 0  audio headphones catalog full 1757641194
# 1  audio headphones catalog full 1757641194
# 2  audio headphones catalog full 1757641194
# 3  audio headphones catalog full 1757641194
# 4  audio headphones catalog full 1757641194
#
#                                     source_file        asin  \
# 0  audio_headphones_catalog_full_1757641194.csv  B0BQPNMXQV
# 1  audio_headphones_catalog_full_1757641194.csv  B0CTBCDD6D
# 2  audio_headphones_catalog_full_1757641194.csv  B08WM3LMJF
# 3  audio_headphones_catalog_full_1757641194.csv  B0DGHMNQ5Z
# 4  audio_headphones_catalog_full_1757641194.csv  B0BS1QCFHX
#
#                                            item_name  brand  image_count  \
# 0  JBL Vibe Beam - True Wireless JBL Deep Bass So...    JBL           18
# 1  JBL Tune 720BT - Wireless Over-Ear Headphones ...    JBL           21
# 2  JBL Tune 510BT - Bluetooth headphones with up ...    JBL           24
# ...

# %%
df.describe()
# Out:
#         image_count  review_count  avg_rating      bsr_best  units_per_month  \
# count  17375.000000           0.0         0.0  1.631100e+04              0.0
# mean      19.505381           NaN         NaN  5.876784e+03              NaN
# std        6.920977           NaN         NaN  1.292930e+05              NaN
# min        0.000000           NaN         NaN  1.000000e+00              NaN
# 25%       18.000000           NaN         NaN  7.700000e+01              NaN
# 50%       21.000000           NaN         NaN  3.180000e+02              NaN
# 75%       24.000000           NaN         NaN  1.078500e+03              NaN
# max       27.000000           NaN         NaN  6.922922e+06              NaN
#
#        sales_velocity_daily
# count                   0.0
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
y_row = 'bsr_best'
y = df[y_row]

# %%
x_row = 'image_count'
plt.scatter(df[x_row], y)
plt.xlabel(x_row)
plt.ylabel(y_row)
# Out:
# Text(0, 0.5, 'bsr_best')
